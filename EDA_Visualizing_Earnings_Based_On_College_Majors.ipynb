# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('white')

# %%
url = 'https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/recent-grads.csv'
data = pd.read_csv(url)
data.head()
# Out:
#    Rank  Major_code                                      Major Major_category  \
# 0     1        2419                      PETROLEUM ENGINEERING    Engineering
# 1     2        2416             MINING AND MINERAL ENGINEERING    Engineering
# 2     3        2415                  METALLURGICAL ENGINEERING    Engineering
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4     5        2405                       CHEMICAL ENGINEERING    Engineering
#
#    Total  Sample_size    Men  Women  ShareWomen  Employed      ...        \
# 0   2339           36   2057    282    0.120564      1976      ...
# 1    756            7    679     77    0.101852       640      ...
# 2    856            3    725    131    0.153037       648      ...
# 3   1258           16   1123    135    0.107313       758      ...
# 4  32260          289  21239  11021    0.341631     25694      ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
data.columns.value_counts().sort_index()
# Out:
# College_jobs            1
# Employed                1
# Full_time               1
# Full_time_year_round    1
# Low_wage_jobs           1
# Major                   1
# Major_category          1
# Major_code              1
# Median                  1
# Men                     1
# Non_college_jobs        1
# P25th                   1
# P75th                   1
# Part_time               1
# Rank                    1
# Sample_size             1
# ShareWomen              1
# Total                   1
# Unemployed              1
# Unemployment_rate       1
# Women                   1
# dtype: int64

# %%
data.describe()
# Out:
#              Rank   Major_code          Total  Sample_size            Men  \
# count  173.000000   173.000000     173.000000   173.000000     173.000000
# mean    87.000000  3879.815029   39167.716763   356.080925   16637.358382
# std     50.084928  1687.753140   63354.613919   618.361022   28063.394844
# min      1.000000  1100.000000     124.000000     2.000000     119.000000
# 25%     44.000000  2403.000000    4361.000000    39.000000    2110.000000
# 50%     87.000000  3608.000000   15058.000000   130.000000    5347.000000
# 75%    130.000000  5503.000000   38844.000000   338.000000   14440.000000
# max    173.000000  6403.000000  393735.000000  4212.000000  173809.000000
#
#                Women  ShareWomen       Employed      Full_time      Part_time  \
# count     173.000000  173.000000     173.000000     173.000000     173.000000
# mean    22530.358382    0.522550   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count = data.shape[0]
print 'Before: ',raw_data_count
data = data.dropna()
cleaned_data_count = data.shape[0]
print 'Cleaned: ',cleaned_data_count
# Out:
# Before:  173
# Cleaned:  172

# %%
data.describe()
# Out:
#              Rank   Major_code          Total  Sample_size            Men  \
# count  172.000000   172.000000     172.000000   172.000000     172.000000
# mean    87.075581  3880.273256   39394.715116   358.127907   16723.877907
# std     50.221266  1692.670105   63468.993551   619.578329   28122.182046
# min      1.000000  1100.000000     609.000000     2.000000     119.000000
# 25%     43.750000  2402.750000    4559.750000    42.000000    2177.500000
# 50%     87.500000  3607.500000   15104.000000   131.000000    5434.000000
# 75%    130.250000  5503.250000   38909.750000   339.000000   14631.000000
# max    173.000000  6403.000000  393735.000000  4212.000000  173809.000000
#
#                Women  ShareWomen       Employed      Full_time      Part_time  \
# count     172.000000  172.000000     172.000000     172.000000     172.000000
# mean    22653.656977    0.523090   31374.116279   26179.994186    8883.750000
# ...

# %%
data.plot(x='Sample_size', y='Median', kind='scatter')

# %%
fig, ( (ax1, ax2, ax3), (ax4, ax5, ax6) ) = plt.subplots(2,3, figsize=(18,6))

ax1.scatter(x=data['Sample_size'], y=data['Median'])
ax1.set_xlabel('Sample Size'); ax1.set_ylabel('Median')
for key,spine in ax1.spines.items():
        spine.set_visible(False)

ax2.scatter(data['Sample_size'], data['Unemployment_rate'])
ax2.set_xlabel('Sample Size'); ax2.set_ylabel('Unemployment Rate')
for key,spine in ax2.spines.items():
        spine.set_visible(False)

ax3.scatter(data['Full_time'], data['Median'])
ax3.set_xlabel('Full Time'); ax3.set_ylabel('Median')
for key,spine in ax3.spines.items():
        spine.set_visible(False)

ax4.scatter(data['ShareWomen'], data['Unemployment_rate'])
ax4.set_xlabel('Share of Women'); ax4.set_ylabel('Unemployment Rate')
for key,spine in ax4.spines.items():
        spine.set_visible(False)

ax5.scatter(data['Men'], data['Median'])
ax5.set_xlabel('Men'); ax5.set_ylabel('Median')
for key,spine in ax5.spines.items():
        spine.set_visible(False)

ax6.scatter(data['Women'], data['Median'])
ax6.set_xlabel('Women'); ax6.set_ylabel('Median')
for key,spine in ax6.spines.items():
        spine.set_visible(False)

plt.show()

# %% [markdown]
# Use the plots to explore the following questions:
# Do students in more popular majors make more money?
# Do students that majored in subjects that were majority female make more money?
# Is there any link between the number of full-time employees and median salary?

# %%
cols = ["Sample_size", "Median", "Employed", "Full_time", "ShareWomen", "Unemployment_rate", "Men", "Women"]

fig = plt.figure(figsize=(18,16))
for r in range(8):
    ax = fig.add_subplot(4,2,r+1)
    ax = data[cols[r]].plot(kind='hist', rot=0, bins=20)
    ax.set_title(cols[r])
    for key,spine in ax.spines.items():
        spine.set_visible(False)
        
plt.show()

# %% [markdown]
# Use the plots to explore the following questions:
# What percent of majors are predominantly male? Predominantly female?
# What's the most common median salary range?

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(data[['Sample_size', 'Median']], figsize=(16,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1197821d0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c61b710>]], dtype=object)

# %%
scatter_matrix(data[['Sample_size', 'Median', 'Unemployment_rate']], figsize=(16,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11c791590>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ce57bd0>]], dtype=object)

# %%
data[:10].plot.bar(x='Major', y='ShareWomen', legend=False, figsize=(12,3), color='g', rot=90)
data[163:].plot.bar(x='Major', y='ShareWomen', legend=False, figsize=(12,3), color='g')
