# %% [markdown]
# # Stackoverflow Developers Survey 2019

# %% [markdown]
# **Source:** https://insights.stackoverflow.com/survey/2019
#
# The Annual Stackoverflow Developers Survey collects responses from several developers, programmers, software engineers and many others from all over the world. The survey aims to provide a better understanding of the most important and desired items across a myriad of topics.
#
# The **goal of this analysis** is to collect information that could help guide newcomers in the field with regards as where to focus their studies. In other words, what they should learn. Let's explore it a little so we can have a better idea.

# %% [markdown]
# ## Imports

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import pandas as pd
pd.options.display.max_columns=999
pd.options.display.max_rows=999
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## Load the data

# %%
# %ls developer_survey_2019/
# Out:
# README_2019.txt            survey_results_public.csv
# so_survey_2019.pdf         survey_results_schema.csv

# %%
df = pd.read_csv('developer_survey_2019/survey_results_public.csv')
print(df.shape)
df.head(3)
# Out:
# (88883, 85)
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
# 2                    Never  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
#
#           Student                                            EdLevel  \
# ...

# %% [markdown]
# ## Understand the data

# %%
# each line represents an unique response
df.Respondent.nunique() == df.shape[0]
# Out:
# True

# %%
sh = df.shape
f'The data consists of {sh[0]} responses and {sh[1]} columns.'
# Out:
# 'The data consists of 88883 responses and 85 columns.'

# %%
pd.DataFrame((df.isnull().mean()*100).sort_values(ascending=False)).round(2).T
# Out:
#    BlockchainOrg  CodeRevHrs  ConvertedComp  CompTotal  MiscTechWorkedWith  \
# 0           45.8       43.98          37.19      37.06               32.96
#
#    BlockchainIs  PurchaseHow  MgrMoney  MgrIdiot  MgrWant  PurchaseWhat  \
# 0         32.31        31.25     31.19     31.19    31.11         30.21
#
#    UnitTests  WebFrameDesireNextYear  CompFreq  WorkWeekHrs  \
# 0      29.49                   29.18     28.82        27.43
#
#    MiscTechDesireNextYear  WebFrameWorkedWith  LastInt  WorkChallenge  \
# 0                   27.42               26.85    24.45          23.34
#
#    SOHowMuchTime  WorkPlan  DatabaseDesireNextYear  SONewContent  WorkLoc  \
# 0          23.07     22.47                    22.2         21.74    21.18
#
#    WorkRemote  CodeRev  JobSat  FizzBuzz  CurrencyDesc  CurrencySymbol  \
# 0       20.93    20.81   20.13     19.73         19.68           19.68
#
#    ImpSyn  OrgSize  CareerSat  YearsCodePro  SOPartFreq  UndergradMajor  \
# ...

# %% [markdown]
# Most columns have at least 1 missing value. Some have over 30% of nulls, but overall, all columns have over 50% of data.
#
# Let's see how many countries are represented in the survey:

# %%
n_countries = 50
fig, ax = plt.subplots(figsize=(20,3.5))

df.Country.value_counts()[:n_countries].plot(kind='bar', ax=ax)

# formatting
plt.title(f'Top {n_countries} countries according to the number of responses',
          fontsize=14, fontweight='bold')
plt.xticks(rotation=45, horizontalalignment='right')

for sp in ['top', 'right', 'left']:
    ax.spines[sp].set_visible(False)
plt.show()

# %%
f'Unique countries in the data: {df.Country.nunique()}'
# Out:
# 'Unique countries in the data: 179'

# %% [markdown]
# There are respondents from most countries in the world, but it's possible to see that there are many more respondents from the USA, India, Germany, UK and Canada (top 5).

# %%
df.MainBranch.value_counts()
# Out:
# I am a developer by profession                                                   65679
# I am a student who is learning to code                                           10189
# I am not primarily a developer, but I write code sometimes as part of my work     7539
# I code primarily as a hobby                                                       3340
# I used to be a developer by profession, but no longer am                          1584
# Name: MainBranch, dtype: int64

# %% [markdown]
# Most respondents are professional developers, while some are students or code as a hobby.

# %%
df.Employment.value_counts()
# Out:
# Employed full-time                                      64440
# Independent contractor, freelancer, or self-employed     8511
# Not employed, but looking for work                       5600
# Employed part-time                                       4469
# Not employed, and not looking for work                   3803
# Retired                                                   358
# Name: Employment, dtype: int64

# %% [markdown]
# Also, most respondents are currently working in the field.

# %% [markdown]
# Therefore, this survey contains responses from all over the world, mostly from professional developers that are currently working in the field, which makes it an excellent source of information of the latest and most popular tools out there.
#
# With this in mind, let's analyze 4 things that may be of importance for who is planning to get into the field:
# - What education options are available other than formal degrees?
# - What are the most used programming languages?
# - What are the most used platforms?
# - What are the most used database environments?
#
# To investigate more, we will focus on analyzing the answers of the following survey questions:
# - Which of the following types of non-degree education have you used or participated in? Please select all that apply.
#
#
# - Which of the following programming, scripting, and markup languages have you done extensive development work in over the past year, and which do you want to work in over the next year?  (If you both worked with the language and want to continue to do so, please check both boxes in that row.)
#
#
# - Which of the following platforms have you done extensive development work for over the past year?   (If you both developed for the platform and want to continue to do so, please check both boxes in that row.)
#
#
# - Which of the following database environments have you done extensive development work in over the past year, and which do you want to work in over the next year?   (If you both worked with the database and want to continue to do so, please check both boxes in that row.)
#
# Let's proceed!

# %% [markdown]
# ## Exploratory data analysis

# %% [markdown]
# All these responses have multiple possible answers and they are all separated by a `;`. Let's see an example:

# %%
df.LanguageDesireNextYear.iloc[0]
# Out:
# 'C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL'

# %%
df.LanguageDesireNextYear.iloc[0].split(';')
# Out:
# ['C', 'C++', 'C#', 'Go', 'HTML/CSS', 'Java', 'JavaScript', 'Python', 'SQL']

# %% [markdown]
# Therefore, we will need to split these answers into individual items before analyzing them. So, let's build a function to do that so we can follow the DRY principles (Don't Repeat Yourself).

# %%
def expand_cols(series, sep=';'):
    """
    ||Data Preparation||
    Splits items from cell for all questions with multiple possible answers.
    
    Inputs:
        - series: columns from dataframe.
        - sep: separator (where the values will be splitted). Default is ';'.
    
    Output:
        - series with as many items as the number of unique values in the
        original column. This will contain the total number of times each
        response was selected across all respondents.
    """
    
    # expand (splits) the columns 
    _df = series.str.split(sep, expand=True)
    dim = _df.shape[1]
    
    # get unique responses from each respondent
    # no imputation, as we are interested in what the original responses
    unique_vals = [v for v in pd.unique(_df.values.ravel()) if pd.notnull(v)]
    
    # loop to fill in values with 1 or 0
    for val in unique_vals:
        _df.loc[:,val] = _df.iloc[:,:dim].apply(lambda row: 1 if val in set(row) else 0, axis=1)
    
    _df = _df.iloc[:,dim:]
    return _df.sum().sort_values(ascending=False)

# %% [markdown]
# Let's see an example:

# %%
example = df.LanguageDesireNextYear.iloc[:3]
example
# Out:
# 0    C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 1                        C++;HTML/CSS;JavaScript;SQL
# 2                                    Elixir;HTML/CSS
# Name: LanguageDesireNextYear, dtype: object

# %%
expand_cols(example)
# Out:
# HTML/CSS      3
# SQL           2
# JavaScript    2
# C++           2
# Elixir        1
# Python        1
# Java          1
# Go            1
# C#            1
# C             1
# dtype: int64

# %% [markdown]
# As you can see it splits the items, groups them together and sum the number of times each item appears.
#
# Now let's create a function to plot these results:

# %%
def make_barplot(_series, tit, horizontal=False):
    """
    Plots the series item-frequency from the function 'expand_cols'.
    Applies some formatting to the plot, saves it and display it.
    """
    sns.set_style('whitegrid')
    fig, ax = plt.subplots(figsize=(15,4))
    
    if horizontal:
        p = sns.barplot((_series/_series.sum())*100, _series.index, palette="Blues_d")
        plt.xticks(fontsize=11.5)
        plt.xlabel('Frequency (%)')

    else:
        p = sns.barplot(_series.index, (_series/_series.sum())*100, palette="Blues_d")
        plt.xticks(rotation=45, horizontalalignment="right", fontsize=11.5)
        plt.ylabel('Frequency (%)')
    
    for sp in ['right', 'left', 'top']:
        ax.spines[sp].set_visible(False)

    plt.title(tit, fontsize=16, fontweight='bold')
    plt.tight_layout()
    plt.savefig(tit+'.png', dpi=150)
    plt.show()

# %% [markdown]
# This time, let's use both functions to see the results produced:

# %% [markdown]
# ### Non-degree education

# %% [markdown]
# First of all, you don’t necessarily need a degree in the field to start working with data — I’ve done it for years without having one. So, let’s see what are the most popular non-degree education options around:

# %%
## QUESTION:
# Which of the following types of non-degree education have you used or
# participated in? Please select all that apply.

eduo = expand_cols(df.EduOther)
make_barplot(eduo, 'Most popular non-degree education in the field', True)

# %% [markdown]
# As you can see, most people have learned by themselves and with the help of online courses. Frankly, everybody I’ve met so far has taken at least a few online courses on the area and are constantly looking for functions, answers, techniques online. By the way, Stackoverflow is a great source, and it’s very likely that any questions you have about programming and data science have already been answered there.
#
#
# Based on the responses above, you can start right away to learn the skills you need with no excuses.
#
#
# So, what should you focus on learning/improving now? Let’s take a look at one of the most important things you need to know: programming.

# %% [markdown]
# ### Programming languages

# %% [markdown]
# There are many programming languages that have their own ways of getting the tasks done. It’s true that there are several softwares out there that can do most (if not all) data science tasks without the need to write a line of code. However, knowing how to do it sets you apart, as it signals that you mean business. At the very least, it will make you much more autonomous and efficient in you daily work (not to mention the personal satisfaction).
#
# Let’s see what were the most used ones in 2019 and/or are the most desired for the comming year:

# %%
## QUESTION:
# Which of the following programming, scripting, and markup languages have you
# done extensive development work in over the past year, and which do you want
# to work in over the next year?  (If you both worked with the language and want
# to continue to do so, please check both boxes in that row.)

langn = expand_cols(df.LanguageDesireNextYear)
make_barplot(langn, 'Most popular programming, scripting and markup languages 2019 & 2020')

# %% [markdown]
# The graph above ranks Python in second place, right after JavaScript (which has other purposes other than data science). As a matter of fact, it has been gaining positions in similar surveys year after year. Note that many of the languages listed above are not meant to be used in data science. Python is, but it has many more uses as well. It is called a “general purpose programming language”, as it has been used in very different tasks, such as web development, Hollywood special movie effects, space exploration, software engineering, data analysis, artificial intelligence, among others.
#
# Another important aspect of it is that (as far as programming goes) it is easy to learn and it has a strong community that is constantly developing it. I’m personally using it daily and I can’t stress enough how important this skill is for my work. Being the most popular programming language for data science, you can rest assure that by using Python you will have access to the latest packages and functions available in the field. Plus, you will be able to do all sorts of things with it. As a simple example, check out how these plots were made in my [GitHub](https://github.com/gestivalet/EDA/tree/master/udacity_StackOVF_Medium).
#
# Next, let’s take a look at the platforms.

# %% [markdown]
# ### Platforms

# %%
## QUESTION:
# Which of the following platforms have you done extensive development work for
# over the past year?   (If you both developed for the platform and want to
# continue to do so, please check both boxes in that row.)

platn = expand_cols(df.PlatformDesireNextYear)
make_barplot(platn, 'Most popular platforms 2019 & 2020')

# %% [markdown]
# Here I’d like to direct your attention to 3 items: Linux, Docker and AWS.
#
# **Linux:** no matter the task you might have to perform, you will have to work with an operational system (Windows, MacOS, Linux, etc.) and knowing how to do so effectively can really help you. As you can see, Linux is the most popular one, as it gives the user a level of flexibility that the others don’t. In addition, it’s open-source and, like Python, has a strong community of developers supporting it. For these reasons, it is the prefered platform choice of many companies.
#
# **Docker:** the logic behind it is that it used containers (environments) where you can deploy your programs and models. Given that it is open-source, flexible, scalable and versatile, it is being adopted as a standard across industries for building, sharing and deploying applications anywhere (cloud, local environment, in different systems and platforms, you name it!). So, learning its fundamentals might be crucial to get the job done. Think about this: no matter how awesome your model is if you can’t deliver the results to your stakeholders. That’s where Docker comes in.
#
# **AWS:** many companys nowadays are migrating their operations to the cloud, which can be much cheaper and efficient to maintain than having in-premisse servers. AWS (Amazon Web Services) is one of the key players and it has all sorts or services that will allow you to quickly deploy virtual machines that would cost a few cents an hour with a scalability that you wouldn’t be able to get otherwise.

# %% [markdown]
# ### Database environments

# %%
## QUESTION:
# Which of the following database environments have you done extensive
# development work in over the past year, and which do you want to work in over
# the next year?   (If you both worked with the database and want to continue
# to do so, please check both boxes in that row.)

dbn = expand_cols(df.DatabaseDesireNextYear)
make_barplot(dbn, 'Most popular database environments 2019 & 2020')

# %% [markdown]
# Finally, you won’t be able to work autonomously without knowing SQL (Structured Query Language). Most databases are relational, meaning that there are potentially several tables holding the information you need and that can/need to be joined together. For that, SQL is used to query (retrieve) that information so you can analyze, build models and deliver results.
#
# On the bright side, it’s a fairly easy to learn language, as it works with a few basic keywords that will get most of the tasks done. In addition to that, you would only need to understand how about the logic behind relational tables, so that you know how to connect the information.
#
# Nonetheless, SQL can get pretty complicated if the schema of the data is complex, as well as if the code needs to be highly optimized. But most things can be done only with some basic knowledge.

# %% [markdown]
# ## Conclusions

# %% [markdown]
# There are many different skills, tools and techniques that one will need to know to work in the area. I have not even mentioned all the mathematical knowledge necessary to analyze and model data, but there are certain skills that can get you started in the field quickly. In hindsight, I can say that learning how to program and work in different platforms really helped me to do so. More specifically, it allowed me to automate many repetitive task that my colleagues and I were performing everyday. Once I saw the benefits, I was hooked.
#
# Sooner or later, though, you will need to work on you math skills. Needless to say, not many lawyers know how to calculate a standard deviation of a data set or understand what role the coefficients play in interpreting a linear equation. But, if I can do it, so can you!
#
# I hope these simple pointers help you decide where to focus your time and effort in the future. Before you go, though, know this: in this area you will never stop studying!
